# %%
import pandas as pd
import os

pwd = os.getcwd()

raw_df = pd.read_csv(pwd+"\\screening.csv", delimiter=',')

# %%
df = raw_df.copy()
df
# Out:
#    Response ID,"Date submitted","Last page","Start language","Seed","Date started","Date last action","What is the participant ID that was given to you by the researchers? ","What is your age?","What is your gender? ","What is your nationality? ","Are you able to comfortably use english to understand and answer questions?","Do any of the following points apply to you?   \tI am diagnosed with a psychological or psychiatric disorder \tI am diagnosed with a chronic disease \tI take medication every day (birth control pill excluded)  \tI am currently pregnant, or there is a chance that I am pregnant \tI am currently experiencing symptoms of Covid 19  \tI received a positive result to a Covid 19 test in the past 7 days \tI consume recreational drugs regularly \tI smoke cigarettes every day  ","How do you normally travel to your work/university? ","How do you normally travel to your work/university?  [Comment]","Do you have normal or corrected (by glasses or contact lenses) vision? ","What
# ...

# %%
df.iloc[:, : 10]
# Out:
#    Response ID,"Date submitted","Last page","Start language","Seed","Date started","Date last action","What is the participant ID that was given to you by the researchers? ","What is your age?","What is your gender? ","What is your nationality? ","Are you able to comfortably use english to understand and answer questions?","Do any of the following points apply to you?   \tI am diagnosed with a psychological or psychiatric disorder \tI am diagnosed with a chronic disease \tI take medication every day (birth control pill excluded)  \tI am currently pregnant, or there is a chance that I am pregnant \tI am currently experiencing symptoms of Covid 19  \tI received a positive result to a Covid 19 test in the past 7 days \tI consume recreational drugs regularly \tI smoke cigarettes every day  ","How do you normally travel to your work/university? ","How do you normally travel to your work/university?  [Comment]","Do you have normal or corrected (by glasses or contact lenses) vision? ","What
# ...
